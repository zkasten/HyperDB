# %%
import pandas as pd
import requests

t
#curl -X POST "https://api.airtable.com/v0/entbiilze8Kao2jYh/edtv7pdm8oBXZHeDw/getRecords" -H "Authorization: Bearer patRgTOFAFiFMy6Yw.1fb5dc5717d88354eb7f4f5c6dd76a7907d5a656fd925d80b0201852117f82a3" -H "Content-Type: application/json" --data '{ "fields": [] }'

# --- 설정 ---
# 본인의 Airtable 정보로 수정해주세요.
API_KEY = "patRgTOFAFiFMy6Yw.1fb5dc5717d88354eb7f4f5c6dd76a7907d5a656fd925d80b0201852117f82a3"
BASE_ID = "entbiilze8Kao2jYh"
TABLE_NAME = "edtv7pdm8oBXZHeDw"

# Airtable API 엔드포인트 (POST로 레코드를 가져올 때는 /listRecords 사용)
url = f"https://api.airtable.com/v0/{BASE_ID}/{TABLE_NAME}/getRecords"

# --- 요청 헤더 ---
# curl -H 부분에 해당합니다.
headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

dic={}
arr=[]
arr.append('Item')
dic['fields'] = []
# print(arr)
# print(dic)

pkey_lst = []

# --- 요청 실행 및 데이터 처리 ---
try:
    # POST 요청을 보냅니다.
    # 본문(payload)을 비워두면 모든 필드를 가져옵니다.
    response = requests.post(url, headers=headers, json=dic)
    
    # HTTP 요청이 성공했는지 확인 (에러 시 예외 발생)
    response.raise_for_status()

    # JSON 응답을 파이썬 딕셔너리로 변환
    airtable_response = response.json()
    
    # 실제 데이터는 'records' 키 안에 들어있습니다.
    records_data = airtable_response.get('records', [])
    
    j=1
    for i in records_data:
        pkey_lst.append(i['primaryKey'])
        # print(i)
        j += 1
        if j > 50:
            break
        


    # for k in pkey_lst:
    #     if k == '1317102349':
    #         print('match')
    #     if k == '1317102348':
    #         print('match')
    #     if k == '1317102347':
    #         print('match')

    # pkey_lst.append('')
    # pkey_lst.append('1317102349')
    # pkey_lst.append('1317102348')
    # pkey_lst.append('1317102347')
    
    # print(len(pkey_lst))
    # print(pkey_lst)

    # # 각 레코드의 'fields' 딕셔너리만 추출하여 리스트로 만듭니다.
    # data_for_df = [record['fields'] for record in records_data]j

    # # 추출한 데이터로 Pandas DataFrame 생성
    # df = pd.DataFrame(data_for_df)

    # # 결과 확인
    # print("✅ 데이터프레임 생성 성공!")
    # print(df.head())

except requests.exceptions.RequestException as e:
    print(f"❌ API 요청 중 에러 발생: {e}")
except (KeyError, IndexError) as e:
    print(f"❌ JSON 데이터 처리 중 에러 발생: 응답 형식을 확인하세요. ({e})")

# %%
print(len(pkey_lst))
# print(pkey_lst)
# dic={}
# dic['primaryKeys'] = pkey_lst
# print(dic)
# Out:
# 50

# %%
print(pkey_lst)

url_del = f"https://api.airtable.com/v0/{BASE_ID}/{TABLE_NAME}/deleteRecords"
# arr=[]
# arr.append('1317102347')
# arr.append('1317102349')
# arr.append('1317102348')
dic={}
dic['primaryKeysForDelete'] = pkey_lst
# dic['primaryKeysForDelete'] = arr


# --- 요청 실행 및 데이터 처리 ---
try:
    # POST 요청을 보냅니다.
    # 본문(payload)을 비워두면 모든 필드를 가져옵니다.
    response = requests.post(url_del, headers=headers, json=dic)
    print(response)
    
    # HTTP 요청이 성공했는지 확인 (에러 시 예외 발생)
    response.raise_for_status()

    # JSON 응답을 파이썬 딕셔너리로 변환
    airtable_response = response.json()
    print(airtable_response)
    
    # 실제 데이터는 'records' 키 안에 들어있습니다.
    records_data = airtable_response.get('records', [])
    print(records_data)
    
    
    # for i in records_data:
    #     pkey_lst.append(i['primaryKey'])
    #     # print(i)
    #     # j += 1
    #     # if j > 100:
    #     #     break


    # for k in pkey_lst:
    #     if k == '1317102349':
    #         print('match')
    #     if k == '1317102348':
    #         print('match')
    #     if k == '1317102347':
    #         print('match')

    # # pkey_lst.append('')
    # pkey_lst.append('1317102349')
    # pkey_lst.append('1317102348')
    # pkey_lst.append('1317102347')
    
    # print(len(pkey_lst))
    # print(pkey_lst)

    # # 각 레코드의 'fields' 딕셔너리만 추출하여 리스트로 만듭니다.
    # data_for_df = [record['fields'] for record in records_data]

    # # 추출한 데이터로 Pandas DataFrame 생성
    # df = pd.DataFrame(data_for_df)

    # # 결과 확인
    # print("✅ 데이터프레임 생성 성공!")
    # print(df.head())

except requests.exceptions.RequestException as e:
    print(f"❌ API 요청 중 에러 발생: {e}")
except (KeyError, IndexError) as e:
    print(f"❌ JSON 데이터 처리 중 에러 발생: 응답 형식을 확인하세요. ({e})")
# Out:
# ['1303301150', '2304208037', '3323006017', '3323006024', '1303301006', '1303301066', '1308101099', '2312403097', '1303301052', '1303301185', '1308101085', '1319402039', '3311201051', '3315101151', '1317106242', '3315104165', '1303301239', '1302301020', '1317102012', '1302101029', '3323002233', '2319399001', '1303201153', '1303302003', '1303303007', '1302202015', '1319203001', '3323002043', '1308101208', '1317106488', '1319402038', '1317102006', '1317102021', '1303301122', '1302600013', '1317107223', '1308102008', '3323005036', '1319299040', '3323005031', '1317101641', '1314101018', '1308104013', '1308101110', '1317106435', '3323002033', '1307301116', '1317199319', '1317106295', '1319402009']
# <Response [200]>
# ❌ API 요청 중 에러 발생: Expecting value: line 1 column 1 (char 0)
